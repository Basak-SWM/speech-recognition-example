# %%
import numpy as np
import librosa

# Load the audio files
y1, sr1 = librosa.load('full.wav')
y2, sr2 = librosa.load('record.wav')

# It's important that the sample rates match - if they don't, you can resample.
if sr1 != sr2:
    y2 = librosa.resample(y2, sr2, sr1)
    
# Cross-correlate the signals
xcorr = np.correlate(y1, y2, mode='full')

# Find the lag that maximizes the cross-correlation
lag = np.argmax(xcorr)

# Convert lag to seconds
lag_in_seconds = lag / sr1

print(f"The most similar part to b.wav starts at {lag_in_seconds} seconds into a.wav.")


# Plot the signal stored in 'y'
from matplotlib import pyplot as plt
import librosa.display

plt.figure(figsize=(12, 3))
plt.title("전체 스크립트")
librosa.display.waveshow(y1, sr=sr1);


plt.figure(figsize=(12, 3))
plt.title("말버릇")
librosa.display.waveshow(y2, sr=sr2);
# Out:
# The most similar part to b.wav starts at 20.475646258503403 seconds into a.wav.
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\librosa\display.py:806: UserWarning: Glyph 47495 (\N{HANGUL SYLLABLE REUS}) missing from current font.
#   ax.figure.canvas.draw_idle()
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47495 (\N{HANGUL SYLLABLE REUS}) missing from current font.
#   func(*args, **kwargs)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52404 (\N{HANGUL SYLLABLE CE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47549 (\N{HANGUL SYLLABLE RIB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47568 (\N{HANGUL SYLLABLE MAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\cyh\programming\speech-recognition-example\venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47495 (\N{HANGUL SYLLABLE REUS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
